# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
bst = xgb.Booster(model_file='xgb.model')

# %%
ax = xgb.plot_importance(bst)

# %%
ax = xgb.plot_importance(bst, color='r', title='t', xlabel='x', ylabel='y')

# %%
ax = xgb.plot_importance(bst, color=['r', 'r', 'b', 'b'],
                         title=None, xlabel=None, ylabel=None)

# %%
g = xgb.to_graphviz(bst, num_trees=0)

# %%
ax = xgb.to_graphviz(bst, num_trees=0)

# %%
np.random.seed(1)

# %%
dm = xgb.DMatrix(np.random.randn(100, 100), label=[0, 1]*50)

# %%
bst = xgb.train({}, dm)

# %%
ax = xgb.plot_importance(bst)

# %%
ax = xgb.plot_importance(bst, xlim=(0, 5), ylim=(10, 71))
